# %% [markdown]
# # Final Project
# ## The 5 stocks we chose are AMC, AT&T, FaceBook, Microsoft and Tesla

# %% [markdown]
# ### Part 1

# %%
# !pip install yfinance

import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
amc = yf.Ticker("AMC")
hist = amc.history(period="800d")
hist.head()

amc = hist.loc['2019-01-01': '2019-12-31']
amc.head()
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2019-01-02  11.100935  12.089944  10.999260  11.914326  1374900        0.0
# 2019-01-03  11.831137  12.515124  11.674004  12.071457  1392400        0.0
# 2019-01-04  12.219346  12.653770  12.034485  12.515124  1025000        0.0
# 2019-01-07  12.524369  13.180627  12.357993  13.051224  1119200        0.0
# 2019-01-08  13.134409  13.587319  13.023492  13.467159  1122700        0.0
#
#             Stock Splits
# Date
# 2019-01-02             0
# 2019-01-03             0
# 2019-01-04             0
# 2019-01-07             0
# 2019-01-08             0

# %%
amc #displays count
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2019-01-02  11.100935  12.089944  10.999260  11.914326  1374900        0.0
# 2019-01-03  11.831137  12.515124  11.674004  12.071457  1392400        0.0
# 2019-01-04  12.219346  12.653770  12.034485  12.515124  1025000        0.0
# 2019-01-07  12.524369  13.180627  12.357993  13.051224  1119200        0.0
# 2019-01-08  13.134409  13.587319  13.023492  13.467159  1122700        0.0
# ...               ...        ...        ...        ...      ...        ...
# 2019-12-24   7.424451   7.623232   7.384695   7.464208  3618200        0.0
# 2019-12-26   7.503964   7.513903   7.275366   7.295244  3305800        0.0
# 2019-12-27   7.255488   7.354878   7.156097   7.255488  3910500        0.0
# 2019-12-30   7.265427   7.374756   7.185915   7.195854  3371000        0.0
# 2019-12-31   7.195854   7.255488   7.106403   7.195854  3279000        0.0
#
#             Stock Splits
# Date
# 2019-01-02             0
# ...

# %%
att = yf.Ticker("T")
hist = att.history(period="800d")
hist.head()

att = hist.loc['2019-01-01': '2019-12-31']
att.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  24.245329  25.172607  24.075186  25.130072  39294000        0.0
# 2019-01-03  25.113056  25.359762  24.849334  25.164099  37603600        0.0
# 2019-01-04  25.487368  25.844668  25.427819  25.810640  42072400        0.0
# 2019-01-07  26.142416  26.601802  25.878696  26.278530  41070900        0.0
# 2019-01-08  26.635832  26.695382  26.397633  26.610312  43567300        0.0
#
#             Stock Splits
# Date
# 2019-01-02             0
# 2019-01-03             0
# 2019-01-04             0
# 2019-01-07             0
# 2019-01-08             0

# %%
att #displays count
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  24.245329  25.172607  24.075186  25.130072  39294000        0.0
# 2019-01-03  25.113056  25.359762  24.849334  25.164099  37603600        0.0
# 2019-01-04  25.487368  25.844668  25.427819  25.810640  42072400        0.0
# 2019-01-07  26.142416  26.601802  25.878696  26.278530  41070900        0.0
# 2019-01-08  26.635832  26.695382  26.397633  26.610312  43567300        0.0
# ...               ...        ...        ...        ...       ...        ...
# 2019-12-24  35.355535  35.373620  35.174691  35.228943   8697200        0.0
# 2019-12-26  35.256080  35.445968  35.237994  35.409798  19818000        0.0
# 2019-12-27  35.482128  35.590635  35.445958  35.482128  15430700        0.0
# 2019-12-30  35.509258  35.518299  35.247030  35.301285  17665900        0.0
# 2019-12-31  35.274156  35.364582  35.138523  35.337456  20216500        0.0
#
#             Stock Splits
# Date
# ...

# %%
fb = yf.Ticker("T")
hist = fb.history(period="800d")
hist.head()

fb = hist.loc['2019-01-01': '2019-12-31']
fb.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  24.245329  25.172607  24.075186  25.130072  39294000        0.0
# 2019-01-03  25.113056  25.359762  24.849334  25.164099  37603600        0.0
# 2019-01-04  25.487368  25.844668  25.427819  25.810640  42072400        0.0
# 2019-01-07  26.142416  26.601802  25.878696  26.278530  41070900        0.0
# 2019-01-08  26.635832  26.695382  26.397633  26.610312  43567300        0.0
#
#             Stock Splits
# Date
# 2019-01-02             0
# 2019-01-03             0
# 2019-01-04             0
# 2019-01-07             0
# 2019-01-08             0

# %%
fb #displays count
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  24.245329  25.172607  24.075186  25.130072  39294000        0.0
# 2019-01-03  25.113056  25.359762  24.849334  25.164099  37603600        0.0
# 2019-01-04  25.487368  25.844668  25.427819  25.810640  42072400        0.0
# 2019-01-07  26.142416  26.601802  25.878696  26.278530  41070900        0.0
# 2019-01-08  26.635832  26.695382  26.397633  26.610312  43567300        0.0
# ...               ...        ...        ...        ...       ...        ...
# 2019-12-24  35.355535  35.373620  35.174691  35.228943   8697200        0.0
# 2019-12-26  35.256080  35.445968  35.237994  35.409798  19818000        0.0
# 2019-12-27  35.482128  35.590635  35.445958  35.482128  15430700        0.0
# 2019-12-30  35.509258  35.518299  35.247030  35.301285  17665900        0.0
# 2019-12-31  35.274156  35.364582  35.138523  35.337456  20216500        0.0
#
#             Stock Splits
# Date
# ...

# %%
microsoft = yf.Ticker("MSFT")
hist =microsoft.history(period="800d")
hist.head()

microsoft = hist.loc['2019-01-01': '2019-12-31']
microsoft.head()
# Out:
#                   Open        High        Low       Close    Volume  \
# Date
# 2019-01-02   96.848093   98.988379  96.254648   98.375481  35329300
# 2019-01-03   97.383170   97.470732  94.561878   94.756454  42579100
# 2019-01-04   97.013496   99.727773  96.244936   99.163513  44060600
# 2019-01-07   98.881371  100.467129  98.239288   99.289970  35656100
# 2019-01-08  100.243372  101.148131  98.949468  100.009888  31514400
#
#             Dividends  Stock Splits
# Date
# 2019-01-02        0.0             0
# 2019-01-03        0.0             0
# 2019-01-04        0.0             0
# 2019-01-07        0.0             0
# 2019-01-08        0.0             0

# %%
microsoft #displays count
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2019-01-02   96.848093   98.988379   96.254648   98.375481  35329300
# 2019-01-03   97.383170   97.470732   94.561878   94.756454  42579100
# 2019-01-04   97.013496   99.727773   96.244936   99.163513  44060600
# 2019-01-07   98.881371  100.467129   98.239288   99.289970  35656100
# 2019-01-08  100.243372  101.148131   98.949468  100.009888  31514400
# ...                ...         ...         ...         ...       ...
# 2019-12-24  155.471121  155.698198  155.115713  155.372406   8989200
# 2019-12-26  155.550109  156.705183  155.392147  156.645950  14520600
# 2019-12-27  157.415991  157.514721  156.201685  156.932251  18412800
# 2019-12-30  156.961877  156.991493  154.730697  155.579727  16348400
# 2019-12-31  154.770195  155.757438  154.454269  155.688324  18369400
#
#             Dividends  Stock Splits
# Date
# 2019-01-02        0.0             0
# 2019-01-03        0.0             0
# ...

# %%
tesla = yf.Ticker("TSLA")
hist =tesla.history(period="800d")
hist.head()

tesla = hist.loc['2019-01-01': '2019-12-31']
tesla.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  61.220001  63.026001  59.759998  62.023998  58293000          0
# 2019-01-03  61.400002  61.880001  59.476002  60.071999  34826000          0
# 2019-01-04  61.200001  63.599998  60.546001  63.537998  36970500          0
# 2019-01-07  64.344002  67.348000  63.549999  66.991997  37756000          0
# 2019-01-08  68.391998  68.802002  65.403999  67.070000  35042500          0
#
#             Stock Splits
# Date
# 2019-01-02           0.0
# 2019-01-03           0.0
# 2019-01-04           0.0
# 2019-01-07           0.0
# 2019-01-08           0.0

# %%
tesla #displays count
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  61.220001  63.026001  59.759998  62.023998  58293000          0
# 2019-01-03  61.400002  61.880001  59.476002  60.071999  34826000          0
# 2019-01-04  61.200001  63.599998  60.546001  63.537998  36970500          0
# 2019-01-07  64.344002  67.348000  63.549999  66.991997  37756000          0
# 2019-01-08  68.391998  68.802002  65.403999  67.070000  35042500          0
# ...               ...        ...        ...        ...       ...        ...
# 2019-12-24  83.671997  85.094002  82.538002  85.050003  40273500          0
# 2019-12-26  85.582001  86.695999  85.269997  86.188004  53169500          0
# 2019-12-27  87.000000  87.061996  85.222000  86.075996  49728500          0
# 2019-12-30  85.758003  85.800003  81.851997  82.940002  62932000          0
# 2019-12-31  81.000000  84.258003  80.416000  83.666000  51428500          0
#
#             Stock Splits
# Date
# ...

# %%
SP = yf.Ticker("AMC")
hist = SP.history(period="800d")
hist.head()

SP = hist.loc['2019-01-01': '2019-12-31']
SP.head()
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2019-01-02  11.100935  12.089944  10.999260  11.914326  1374900        0.0
# 2019-01-03  11.831137  12.515124  11.674004  12.071457  1392400        0.0
# 2019-01-04  12.219346  12.653770  12.034485  12.515124  1025000        0.0
# 2019-01-07  12.524369  13.180627  12.357993  13.051224  1119200        0.0
# 2019-01-08  13.134409  13.587319  13.023492  13.467159  1122700        0.0
#
#             Stock Splits
# Date
# 2019-01-02             0
# 2019-01-03             0
# 2019-01-04             0
# 2019-01-07             0
# 2019-01-08             0

# %%
SP = yf.Ticker("T")
hist = SP.history(period="800d")
hist.head()

SP = hist.loc['2019-01-01': '2019-12-31']
SP.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  24.245329  25.172607  24.075186  25.130072  39294000        0.0
# 2019-01-03  25.113056  25.359762  24.849334  25.164099  37603600        0.0
# 2019-01-04  25.487368  25.844668  25.427819  25.810640  42072400        0.0
# 2019-01-07  26.142416  26.601802  25.878696  26.278530  41070900        0.0
# 2019-01-08  26.635832  26.695382  26.397633  26.610312  43567300        0.0
#
#             Stock Splits
# Date
# 2019-01-02             0
# 2019-01-03             0
# 2019-01-04             0
# 2019-01-07             0
# 2019-01-08             0

# %%
SP = yf.Ticker("FB")
hist = SP.history(period="800d")
hist.head()

SP = hist.loc['2019-01-01': '2019-12-31']
SP.head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2019-01-02  128.990005  137.509995  128.559998  135.679993  28146200
# 2019-01-03  134.690002  137.169998  131.119995  131.740005  22717900
# 2019-01-04  134.009995  138.000000  133.750000  137.949997  29002100
# 2019-01-07  137.559998  138.869995  135.910004  138.050003  20089300
# 2019-01-08  139.889999  143.139999  139.539993  142.529999  26263800
#
#             Dividends  Stock Splits
# Date
# 2019-01-02          0             0
# 2019-01-03          0             0
# 2019-01-04          0             0
# 2019-01-07          0             0
# 2019-01-08          0             0

# %%
SP = yf.Ticker("MSFT")
hist = SP.history(period="800d")
hist.head()

SP = hist.loc['2019-01-01': '2019-12-31']
SP.head()
# Out:
#                   Open        High        Low       Close    Volume  \
# Date
# 2019-01-02   96.848093   98.988379  96.254648   98.375481  35329300
# 2019-01-03   97.383170   97.470732  94.561878   94.756454  42579100
# 2019-01-04   97.013496   99.727773  96.244936   99.163513  44060600
# 2019-01-07   98.881371  100.467129  98.239288   99.289970  35656100
# 2019-01-08  100.243372  101.148131  98.949468  100.009888  31514400
#
#             Dividends  Stock Splits
# Date
# 2019-01-02        0.0             0
# 2019-01-03        0.0             0
# 2019-01-04        0.0             0
# 2019-01-07        0.0             0
# 2019-01-08        0.0             0

# %%
SP = yf.Ticker("TSLA")
hist = SP.history(period="800d")
hist.head()

SP = hist.loc['2019-01-01': '2019-12-31']
SP.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  61.220001  63.026001  59.759998  62.023998  58293000          0
# 2019-01-03  61.400002  61.880001  59.476002  60.071999  34826000          0
# 2019-01-04  61.200001  63.599998  60.546001  63.537998  36970500          0
# 2019-01-07  64.344002  67.348000  63.549999  66.991997  37756000          0
# 2019-01-08  68.391998  68.802002  65.403999  67.070000  35042500          0
#
#             Stock Splits
# Date
# 2019-01-02           0.0
# 2019-01-03           0.0
# 2019-01-04           0.0
# 2019-01-07           0.0
# 2019-01-08           0.0

# %% [markdown]
# ## Part 2

# %%
amc.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean    11.198204   11.408307   10.952891   11.163329  2.293446e+06
# std      2.148158    2.176506    2.128828    2.163592  1.468843e+06
# min      7.195854    7.255488    7.106403    7.195854  5.460000e+05
# 25%      9.381948    9.516436    9.002165    9.327663  1.394725e+06
# 50%     10.963496   11.114224   10.720180   10.906246  1.883050e+06
# 75%     12.935683   13.236084   12.773930   12.968036  2.746850e+06
# max     15.534952   15.994067   15.319450   15.544322  1.104280e+07
#
#         Dividends  Stock Splits
# count  252.000000         252.0
# mean     0.003175           0.0
# std      0.025047           0.0
# min      0.000000           0.0
# 25%      0.000000           0.0
# 50%      0.000000           0.0
# 75%      0.000000           0.0
# max      0.200000           0.0

# %%
amc.loc[:,'percent change in close in amc',] = amc.loc[:,'Close'].pct_change()

# %%
amc.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'percent change in close in amc'],
#       dtype='object')

# %%
std = amc.loc[:,'percent change in close in amc'].std()
print("The standard deviation of amc is", std)
print("The variance is", std*std)
# Out:
# The standard deviation of amc is 0.02810393400963443
# The variance is 0.0007898311068178867

# %%
amc = amc.reset_index()
amc
amc.head()
# Out:
#         Date       Open       High        Low      Close   Volume  Dividends  \
# 0 2019-01-02  11.100935  12.089944  10.999260  11.914326  1374900        0.0
# 1 2019-01-03  11.831137  12.515124  11.674004  12.071457  1392400        0.0
# 2 2019-01-04  12.219346  12.653770  12.034485  12.515124  1025000        0.0
# 3 2019-01-07  12.524369  13.180627  12.357993  13.051224  1119200        0.0
# 4 2019-01-08  13.134409  13.587319  13.023492  13.467159  1122700        0.0
#
#    Stock Splits  percent change in close in amc
# 0             0                             NaN
# 1             0                        0.013188
# 2             0                        0.036753
# 3             0                        0.042836
# 4             0                        0.031869

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(amc['Date'], amc['percent change in close in amc'], color = 'orange')
plt.title('percent change in close in amc')
plt.xlabel("date")
plt.ylabel("% change in closing price")
plt.show()

# %%
SP.loc[:,'percent change in close in SP500'] = SP.loc[:,'Close'].pct_change()
SP.head()
# Out:
# C:\Users\HCL\Anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\HCL\Anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-01-02  61.220001  63.026001  59.759998  62.023998  58293000          0
# ...

# %%
AMC = amc['percent change in close in amc']
SP500 = SP['percent change in close in SP500']
AMC = AMC.iloc[1:]
SP500 = SP500.iloc[1:]
AMC
amc_stock = np.array([AMC,SP500])
amc_stock = amc_stock.transpose()
amc_stock = pd.DataFrame(amc_stock, columns = ['percent change in close in amc',
                                               'percent change in close in SP500'])
amc_stock
amc_stock.head()
# Out:
#    percent change in close in amc  percent change in close in SP500
# 0                        0.013188                         -0.031472
# 1                        0.036753                          0.057697
# 2                        0.042836                          0.054361
# 3                        0.031869                          0.001164
# 4                       -0.042553                          0.009483

# %%
amc_stock #total count
# Out:
#      percent change in close in amc  percent change in close in SP500
# 0                          0.013188                         -0.031472
# 1                          0.036753                          0.057697
# 2                          0.042836                          0.054361
# 3                          0.031869                          0.001164
# 4                         -0.042553                          0.009483
# ..                              ...                               ...
# 246                        0.025956                          0.014384
# 247                       -0.022636                          0.013380
# 248                       -0.005450                         -0.001300
# 249                       -0.008219                         -0.036433
# 250                        0.000000                          0.008753
#
# [251 rows x 2 columns]

# %%
# Working on the plot

# %%
att.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean    30.016576   30.226168   29.803420   30.037528  3.004444e+07
# std      3.314359    3.318891    3.309671    3.311201  1.209344e+07
# min     24.245329   25.172607   24.075186   25.130072  8.697200e+06
# 25%     26.937091   27.092445   26.742196   26.910802  2.315760e+07
# 50%     29.120618   29.545355   28.813700   29.309793  2.697265e+07
# 75%     33.547703   33.788525   33.262669   33.506075  3.387520e+07
# max     35.581593   35.898085   35.491172   35.834789  1.178660e+08
#
#         Dividends  Stock Splits
# count  252.000000         252.0
# mean     0.008095           0.0
# std      0.063869           0.0
# min      0.000000           0.0
# 25%      0.000000           0.0
# 50%      0.000000           0.0
# 75%      0.000000           0.0
# max      0.510000           0.0

# %%
att.loc[:,'percent change in close in att',] = att.loc[:,'Close'].pct_change()

# %%
std = att.loc[:,'percent change in close in att'].std()
print("The standard deviation of att is", std)
print("The variance is", std*std)
# Out:
# The standard deviation of att is 0.011216038116257614
# The variance is 0.00012579951102534366

# %%
att = att.reset_index()
att
att.head()
# Out:
#         Date       Open       High        Low      Close    Volume  Dividends  \
# 0 2019-01-02  24.245329  25.172607  24.075186  25.130072  39294000        0.0
# 1 2019-01-03  25.113056  25.359762  24.849334  25.164099  37603600        0.0
# 2 2019-01-04  25.487368  25.844668  25.427819  25.810640  42072400        0.0
# 3 2019-01-07  26.142416  26.601802  25.878696  26.278530  41070900        0.0
# 4 2019-01-08  26.635832  26.695382  26.397633  26.610312  43567300        0.0
#
#    Stock Splits  percent change in close in att
# 0             0                             NaN
# 1             0                        0.001354
# 2             0                        0.025693
# 3             0                        0.018128
# 4             0                        0.012626

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(att['Date'], att['percent change in close in att'], color = 'green')
ax.set_facecolor('xkcd:salmon')
plt.title('percent change in close in att')
plt.xlabel("date")
plt.ylabel("% change in closing price")
plt.show()

# %%
ATT = att['percent change in close in att']
SP500 = SP['percent change in close in SP500']
ATT = ATT.iloc[1:]
SP500 = SP500.iloc[1:]
ATT
att_stock = np.array([AMC,SP500])
att_stock = att_stock.transpose()
att_stock = pd.DataFrame(att_stock, columns = ['percent change in close in att',
                                               'percent change in close in SP500'])
att_stock
att_stock.head()
# Out:
#    percent change in close in att  percent change in close in SP500
# 0                        0.013188                         -0.031472
# 1                        0.036753                          0.057697
# 2                        0.042836                          0.054361
# 3                        0.031869                          0.001164
# 4                       -0.042553                          0.009483

# %%
#working on the plot

# %%
fb.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean    30.016576   30.226168   29.803420   30.037528  3.004444e+07
# std      3.314359    3.318891    3.309671    3.311201  1.209344e+07
# min     24.245329   25.172607   24.075186   25.130072  8.697200e+06
# 25%     26.937091   27.092445   26.742196   26.910802  2.315760e+07
# 50%     29.120618   29.545355   28.813700   29.309793  2.697265e+07
# 75%     33.547703   33.788525   33.262669   33.506075  3.387520e+07
# max     35.581593   35.898085   35.491172   35.834789  1.178660e+08
#
#         Dividends  Stock Splits
# count  252.000000         252.0
# mean     0.008095           0.0
# std      0.063869           0.0
# min      0.000000           0.0
# 25%      0.000000           0.0
# 50%      0.000000           0.0
# 75%      0.000000           0.0
# max      0.510000           0.0

# %%
fb.loc[:,'percent change in close in fb',] = fb.loc[:,'Close'].pct_change()

# %%
std = fb.loc[:,'percent change in close in fb'].std()
print("The standard deviation of fb is", std)
print("The variance is", std*std)
# Out:
# The standard deviation of fb is 0.011216038116257614
# The variance is 0.00012579951102534366

# %%
fb = fb.reset_index()
fb
fb.head()
# Out:
#         Date       Open       High        Low      Close    Volume  Dividends  \
# 0 2019-01-02  24.245329  25.172607  24.075186  25.130072  39294000        0.0
# 1 2019-01-03  25.113056  25.359762  24.849334  25.164099  37603600        0.0
# 2 2019-01-04  25.487368  25.844668  25.427819  25.810640  42072400        0.0
# 3 2019-01-07  26.142416  26.601802  25.878696  26.278530  41070900        0.0
# 4 2019-01-08  26.635832  26.695382  26.397633  26.610312  43567300        0.0
#
#    Stock Splits  percent change in close in fb
# 0             0                            NaN
# 1             0                       0.001354
# 2             0                       0.025693
# 3             0                       0.018128
# 4             0                       0.012626

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(fb['Date'], fb['percent change in close in fb'], color = 'green')
ax.set_facecolor('xkcd:salmon')
plt.title('percent change in close in fb')
plt.xlabel("date")
plt.ylabel("% change in closing price")
plt.show()

# %%
FB = fb['percent change in close in fb']
SP500 = SP['percent change in close in SP500']
FB = FB.iloc[1:]
SP500 = SP500.iloc[1:]
FB
fb_stock = np.array([FB,SP500])
fb_stock = fb_stock.transpose()
fb_stock = pd.DataFrame(fb_stock, columns = ['percent change in close in fb',
                                               'percent change in close in SP500'])
fb_stock
fb_stock.head()
# Out:
#    percent change in close in fb  percent change in close in SP500
# 0                       0.001354                         -0.031472
# 1                       0.025693                          0.057697
# 2                       0.018128                          0.054361
# 3                       0.012626                          0.001164
# 4                      -0.021774                          0.009483

# %%
#working on the plot

# %%
microsoft.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   127.844798  128.718913  126.829602  127.886467  2.458099e+07
# std     15.217171   15.153476   15.162887   15.124555  7.701006e+06
# min     96.848093   97.470732   94.561878   94.756454  8.989200e+06
# 25%    116.565071  117.156147  115.761464  116.596813  1.840832e+07
# 50%    132.742286  133.758966  131.146370  132.600822  2.374750e+07
# 75%    137.359236  137.956797  135.986689  136.869743  2.842352e+07
# max    157.415991  157.514721  156.201685  156.932251  5.563640e+07
#
#         Dividends  Stock Splits
# count  252.000000         252.0
# mean     0.007500           0.0
# std      0.059236           0.0
# min      0.000000           0.0
# 25%      0.000000           0.0
# 50%      0.000000           0.0
# 75%      0.000000           0.0
# max      0.510000           0.0

# %%
microsoft.loc[:,'percent change in close in microsoft',] = microsoft.loc[:,'Close'].pct_change()

# %%
std = microsoft.loc[:,'percent change in close in microsoft'].std()
print("The standard deviation of microsoft is", std)
print("The variance is", std*std)
# Out:
# The standard deviation of microsoft is 0.012509348285843378
# The variance is 0.00015648379453653266

# %%
microsoft = microsoft.reset_index()
microsoft
microsoft.head()
# Out:
#         Date        Open        High        Low       Close    Volume  \
# 0 2019-01-02   96.848093   98.988379  96.254648   98.375481  35329300
# 1 2019-01-03   97.383170   97.470732  94.561878   94.756454  42579100
# 2 2019-01-04   97.013496   99.727773  96.244936   99.163513  44060600
# 3 2019-01-07   98.881371  100.467129  98.239288   99.289970  35656100
# 4 2019-01-08  100.243372  101.148131  98.949468  100.009888  31514400
#
#    Dividends  Stock Splits  percent change in close in microsoft
# 0        0.0             0                                   NaN
# 1        0.0             0                             -0.036788
# 2        0.0             0                              0.046509
# 3        0.0             0                              0.001275
# 4        0.0             0                              0.007251

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(microsoft['Date'], microsoft['percent change in close in microsoft'], color = 'green')
ax.set_facecolor('xkcd:salmon')
plt.title('percent change in close in microsoft')
plt.xlabel("date")
plt.ylabel("% change in closing price")
plt.show()

# %%
MSFT = microsoft['percent change in close in microsoft']
SP500 = SP['percent change in close in SP500']
MSFT = MSFT.iloc[1:]
SP500 = SP500.iloc[1:]
MSFT
microsoft_stock = np.array([MSFT,SP500])
microsoft_stock = microsoft_stock.transpose()
microsoft_stock = pd.DataFrame(microsoft_stock, columns = ['percent change in close in microsoft',
                                               'percent change in close in SP500'])
microsoft_stock
microsoft_stock.head()
# Out:
#    percent change in close in microsoft  percent change in close in SP500
# 0                             -0.036788                         -0.031472
# 1                              0.046509                          0.057697
# 2                              0.001275                          0.054361
# 3                              0.007251                          0.001164
# 4                              0.014300                          0.009483

# %%
#working on the plot

# %%
tesla.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean    54.605627   55.529960   53.722508   54.706040  4.579461e+07
# std     10.469095   10.639957   10.412554   10.606053  2.382350e+07
# min     36.220001   37.335999   35.397999   35.793999  1.232800e+07
# 25%     46.246501   46.954001   45.502499   46.444001  3.028275e+07
# 50%     51.986000   52.796001   51.267000   52.059000  3.872175e+07
# 75%     61.630001   63.230000   60.624999   62.382000  5.325762e+07
# max     87.000000   87.061996   85.269997   86.188004  1.500305e+08
#
#        Dividends  Stock Splits
# count      252.0         252.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
tesla.loc[:,'percent change in close in tesla',] = tesla.loc[:,'Close'].pct_change()

# %%
std = tesla.loc[:,'percent change in close in tesla'].std()
print("The standard deviation of tesla is", std)
print("The variance is", std*std)
# Out:
# The standard deviation of tesla is 0.030817212407586458
# The variance is 0.0009497005805743007

# %%
tesla = tesla.reset_index()
tesla
tesla.head()
# Out:
#         Date       Open       High        Low      Close    Volume  Dividends  \
# 0 2019-01-02  61.220001  63.026001  59.759998  62.023998  58293000          0
# 1 2019-01-03  61.400002  61.880001  59.476002  60.071999  34826000          0
# 2 2019-01-04  61.200001  63.599998  60.546001  63.537998  36970500          0
# 3 2019-01-07  64.344002  67.348000  63.549999  66.991997  37756000          0
# 4 2019-01-08  68.391998  68.802002  65.403999  67.070000  35042500          0
#
#    Stock Splits  percent change in close in tesla
# 0           0.0                               NaN
# 1           0.0                         -0.031472
# 2           0.0                          0.057697
# 3           0.0                          0.054361
# 4           0.0                          0.001164

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(tesla['Date'], tesla['percent change in close in tesla'], color = 'green')
ax.set_facecolor('xkcd:salmon')
plt.title('percent change in close in tesla')
plt.xlabel("date")
plt.ylabel("% change in closing price")
plt.show()

# %%
TSLA = tesla['percent change in close in tesla']
SP500 = SP['percent change in close in SP500']
TSLA = TSLA.iloc[1:]
SP500 = SP500.iloc[1:]
TSLA
tesla_stock = np.array([MSFT,SP500])
tesla_stock = tesla_stock.transpose()
tesla_stock = pd.DataFrame(tesla_stock, columns = ['percent change in close in tesla',
                                               'percent change in close in SP500'])
tesla_stock
tesla_stock.head()
# Out:
#    percent change in close in tesla  percent change in close in SP500
# 0                         -0.036788                         -0.031472
# 1                          0.046509                          0.057697
# 2                          0.001275                          0.054361
# 3                          0.007251                          0.001164
# 4                          0.014300                          0.009483

# %%
#working on the plot

# %% [markdown]
# ## Part 3: Regression analysis

# %% [markdown]
# ### 3.1 Building the model for AMC

# %%
X_amc = amc_stock[['percent change in close in amc']]
y_amc = amc_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_amc, y = y_amc, color = "blue")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("AMC", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %% [markdown]
# #### Cooking the model

# %%
# Creating a linear regression model
model = LinearRegression()

# Fitting the model to the data i.e. building the model
model.fit(X_amc, y_amc)
# Out:
# LinearRegression()

# %%
y_amc_pred = model.predict(X_amc)
X_amc = amc_stock[['percent change in close in amc']]
y_amc = amc_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_amc, y = y_amc, color = "blue")
ax.plot(X_amc, y_pred,color="red")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("AMC", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %%
# Fetching intercept (b0), coefficient (b1), r^2, and mean squared error
print("Intercept:", model.intercept_)
print("Coefficients:",model.coef_)
print("R-square score: ", r2_score(y_amc, y_amc_pred))
print("Mean square error: ", mean_squared_error(y_amc, y_amc_pred))
# Out:
# Intercept: 0.001804780946175511
# Coefficients: [0.08477972]
# R-square score:  0.005977663685634682
# Mean square error:  0.0009402625397426046

# %% [markdown]
# ### 3.2 Building the model for AT&T

# %%
X_att = att_stock[['percent change in close in att']]
y_att = att_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_att, y = y_att, color = "green")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("AT&T", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %% [markdown]
# #### Cooking the model

# %%
# Creating a linear regression model
model = LinearRegression()

# Fitting the model to the data i.e. building the model
model.fit(X_att, y_att)
# Out:
# LinearRegression()

# %%
y_att_pred = model.predict(X_att)
X_att = att_stock[['percent change in close in att']]
y_att = att_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_att, y = y_att, color = "green")
ax.plot(X_att, y_att_pred, color="red")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("AT&T", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %%
# Fetching intercept (b0), coefficient (b1), r^2, and mean squared error
print("Intercept:", model.intercept_)
print("Coefficients:",model.coef_)
print("R-square score: ", r2_score(y_att, y_att_pred))
print("Mean square error: ", mean_squared_error(y_att, y_att_pred))
# Out:
# Intercept: 0.001804780946175511
# Coefficients: [0.08477972]
# R-square score:  0.005977663685634682
# Mean square error:  0.0009402625397426046

# %% [markdown]
# ### 3.3 Building the model for FaceBook

# %%
X_fb = fb_stock[['percent change in close in fb']]
y_fb = fb_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_fb, y = y_fb, color = "purple")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("FaceBook", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %% [markdown]
# #### Cooking the model

# %%
# Creating a linear regression model
model = LinearRegression()

# Fitting the model to the data i.e. building the model
model.fit(X_fb, y_fb)
# Out:
# LinearRegression()

# %%
y_fb_pred = model.predict(X_fb)
X_fb = fb_stock[['percent change in close in fb']]
y_fb = fb_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_fb, y = y_fb, color = "purple")
ax.plot(X_fb, y_fb_pred, color = "red")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("FaceBook", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %%
# Fetching intercept (b0), coefficient (b1), r^2, and mean squared error
print("Intercept:", model.intercept_)
print("Coefficients:",model.coef_)
print("R-square score: ", r2_score(y_fb, y_fb_pred))
print("Mean square error: ", mean_squared_error(y_fb, y_fb_pred))
# Out:
# Intercept: 0.001453633336643734
# Coefficients: [0.15059338]
# R-square score:  0.0030040281161316518
# Mean square error:  0.0009430753519206658

# %% [markdown]
# ### 3.4 Building the model for Microsoft

# %%
X_ms = microsoft_stock[['percent change in close in microsoft']]
y_ms = microsoft_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_ms, y = y_ms, color = "aqua")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("Microsoft", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %% [markdown]
# #### Cooking the model

# %%
# Creating a linear regression model
model = LinearRegression()

# Fitting the model to the data i.e. building the model
model.fit(X_ms, y_ms)
# Out:
# LinearRegression()

# %%
y_ms_pred = model.predict(X_ms)
X_ms = microsoft_stock[['percent change in close in microsoft']]
y_ms = microsoft_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_ms, y = y_ms, color = "aqua")
ax.plot(X_ms, y_ms_pred, color = "red")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("Microsoft", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %%
# Fetching intercept (b0), coefficient (b1), r^2, and mean squared error
print("Intercept:", model.intercept_)
print("Coefficients:",model.coef_)
print("R-square score: ", r2_score(y_ms, y_ms_pred))
print("Mean square error: ", mean_squared_error(y_ms, y_ms_pred))
# Out:
# Intercept: 0.00032777617021453333
# Coefficients: [0.70209348]
# R-square score:  0.08122178835630689
# Mean square error:  0.0008690878496185585

# %% [markdown]
# ### 3.5 Building the model for Tesla

# %%
X_ts = tesla_stock[['percent change in close in tesla']]
y_ts = tesla_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_ts, y = y_ts, color = "lawngreen")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("Tesla", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %% [markdown]
# #### Cooking the model

# %%
# Creating a linear regression model
model = LinearRegression()

# Fitting the model to the data i.e. building the model
model.fit(X_ms, y_ms)
# Out:
# LinearRegression()

# %%
y_ts_pred = model.predict(X_ts)
X_ts = tesla_stock[['percent change in close in tesla']]
y_ts = tesla_stock['percent change in close in SP500']
fig , ax = plt.subplots()
ax.scatter(x = X_ts, y = y_ts, color = "lawngreen")
ax.plot(X_ts, y_ts_pred, color = "red")
ax.set_ylabel("S&P 500", size = 20)
ax.set_xlabel("Tesla", size = 20)
ax.set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %%
# Fetching intercept (b0), coefficient (b1), r^2, and mean squared error
print("Intercept:", model.intercept_)
print("Coefficients:",model.coef_)
print("R-square score: ", r2_score(y_ts, y_ts_pred))
print("Mean square error: ", mean_squared_error(y_ts, y_ts_pred))
# Out:
# Intercept: 0.00032777617021453333
# Coefficients: [0.70209348]
# R-square score:  0.08122178835630689
# Mean square error:  0.0008690878496185585

# %% [markdown]
# ## Comparing the graphs of all the 5 assets

# %%
fig, a = plt.subplots(3, 2, constrained_layout=True)
fig.set_figheight(10)
fig.set_figwidth(10)

a[0, 0].scatter(x = X_amc, y = y_amc, color = "blue")
a[0, 0].plot(X_amc, y_amc_pred,color="red")
a[0, 0].set_ylabel("S&P 500", size = 20)
a[0, 0].set_xlabel("AMC", size = 20)
a[0, 0].set_title("Best fit model", size = 30)

a[0, 1].scatter(x = X_att, y = y_att, color = "green")
a[0, 1].plot(X_att, y_att_pred, color="red")
a[0, 1].set_ylabel("S&P 500", size = 20)
a[0, 1].set_xlabel("AT&T", size = 20)
a[0, 1].set_title("Best fit model", size = 30)

a[1, 0].scatter(x = X_fb, y = y_fb, color = "purple")
a[1, 0].plot(X_fb, y_fb_pred, color = "red")
a[1, 0].set_ylabel("S&P 500", size = 20)
a[1, 0].set_xlabel("FaceBook", size = 20)
a[1, 0].set_title("Best fit model", size = 30)

a[1, 1].scatter(x = X_ms, y = y_ms, color = "aqua")
a[1, 1].plot(X_ms, y_ms_pred, color = "red")
a[1, 1].set_ylabel("S&P 500", size = 20)
a[1, 1].set_xlabel("Microsoft", size = 20)
a[1, 1].set_title("Best fit model", size = 30)

a[2, 0].scatter(x = X_ts, y = y_ts, color = "lawngreen")
a[2, 0].plot(X_ts, y_ts_pred, color = "red")
a[2, 0].set_ylabel("S&P 500", size = 20)
a[2, 0].set_xlabel("Tesla", size = 20)
a[2, 0].set_title("Best fit model", size = 30)
# Out:
# Text(0.5, 1.0, 'Best fit model')

# %% [markdown]
# ### Finding the correlation of the assets against the S&P 500

# %%
data = {
    'amc_stock' : amc_stock['percent change in close in amc'],
    'att_stock' : att_stock['percent change in close in att'],
    'fb_stock' : fb_stock['percent change in close in fb'],
    'microsoft_stock' : microsoft_stock['percent change in close in microsoft'],
    'tesla_stock' : tesla_stock['percent change in close in tesla'],
    'S&P 500' : tesla_stock['percent change in close in SP500']
}

df = pd.DataFrame(data)
df.head()
# Out:
#    amc_stock  att_stock  fb_stock  microsoft_stock  tesla_stock   S&P 500
# 0   0.013188   0.013188  0.001354        -0.036788    -0.036788 -0.031472
# 1   0.036753   0.036753  0.025693         0.046509     0.046509  0.057697
# 2   0.042836   0.042836  0.018128         0.001275     0.001275  0.054361
# 3   0.031869   0.031869  0.012626         0.007251     0.007251  0.001164
# 4  -0.042553  -0.042553 -0.021774         0.014300     0.014300  0.009483

# %%
df[df.columns[:]].corr()['S&P 500'][:]
# Out:
# amc_stock          0.077315
# att_stock          0.077315
# fb_stock           0.054809
# microsoft_stock    0.284994
# tesla_stock        0.284994
# S&P 500            1.000000
# Name: S&P 500, dtype: float64

# %% [markdown]
# ##### As shown above, Microsoft and Tesla have the highest correlation with S&P 500, and
# ##### FaceBook has the lowest correlation with S&P 500.
